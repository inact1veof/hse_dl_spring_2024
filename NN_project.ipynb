# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration, AdamW, get_linear_schedule_with_warmup
from torch.utils.data import DataLoader, Dataset
from datasets import load_metric
from torch.utils.tensorboard import SummaryWriter
from torch.nn.utils.rnn import pad_sequence

import json
import re
import nltk

# %%
pretrained_model_name = "cointegrated/rut5-small"
tokenizer = T5Tokenizer.from_pretrained(pretrained_model_name)
model = T5ForConditionalGeneration.from_pretrained(pretrained_model_name)
# Out:
# C:\Users\inact1ve\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# You are using a model of type mt5 to instantiate a model of type t5. This is not supported for all configurations of models and can yield errors.

# %%
max_input_length = 1000
max_target_length = 400
batch_size = 4
epochs = 5
learning_rate = 2e-5

# %%
def load_data(file_path):
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))
    texts_list = []
    target_list = []
    for item in data:
        if 'text' in item:
            texts_list.append(item['text'])
            target_list.append(item['summary'])
    return texts_list, target_list

# %%
def chunk_text(text, chunk_size=512, padding_token="[PAD]"):
    chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]

    max_length = max(len(chunk) for chunk in chunks)

    padded_chunks = [chunk + padding_token * (max_length - len(chunk)) for chunk in chunks]

    return padded_chunks

# %%
def collate_fn(batch):
    input_ids = [item['input_ids'] for item in batch]
    labels = [item['labels'] for item in batch]
    attention_masks = [item['attention_mask'] for item in batch]

    padded_input_ids = pad_sequence(input_ids, batch_first=True, padding_value=tokenizer.pad_token_id)
    padded_labels = pad_sequence(labels, batch_first=True, padding_value=-100)
    padded_attention_masks = pad_sequence(attention_masks, batch_first=True, padding_value=0)

    padded_input_ids = padded_input_ids.view(batch_size, -1)
    padded_attention_masks = padded_attention_masks.view(batch_size, -1)

    return {'input_ids': padded_input_ids, 'attention_mask': padded_attention_masks, 'labels': padded_labels}

# %%
texts_list_train, summary_list_train = load_data('gazeta_train.jsonl')
texts_list_val, summary_list_val = load_data('gazeta_val.jsonl')
texts_list_test, summary_list_test = load_data('gazeta_test.jsonl')

# %%
class SummaryDataset(Dataset):
    def __init__(self, texts, summaries, tokenizer, max_input_length, max_target_length):
        self.texts = texts
        self.summaries = summaries
        self.tokenizer = tokenizer
        self.max_input_length = max_input_length
        self.max_target_length = max_target_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        summary = self.summaries[idx]

        text_chunks = chunk_text(text, chunk_size=self.max_input_length)

        inputs = []
        attention_masks = []
        for chunk in text_chunks:
            encoded_dict = self.tokenizer.encode_plus(
                "summarize: " + chunk,
                max_length=self.max_input_length,
                padding='max_length',
                truncation=True,
                return_tensors="pt"
            )
            inputs.append(encoded_dict['input_ids'].squeeze(0))
            attention_masks.append(encoded_dict['attention_mask'].squeeze(0))

        input_ids = pad_sequence(inputs, batch_first=True, padding_value=self.tokenizer.pad_token_id)
        attention_mask = pad_sequence(attention_masks, batch_first=True, padding_value=0)

        labels = self.tokenizer.encode(summary, max_length=self.max_target_length, padding='max_length', truncation=True, return_tensors="pt")[0]
        labels[labels == self.tokenizer.pad_token_id] = -100

        return {'input_ids': input_ids, 'attention_mask': attention_mask, 'labels': labels}

# %%
class SummaryDataset(Dataset):
    def __init__(self, texts, summaries, tokenizer, max_input_length, max_target_length):
        self.texts = texts
        self.summaries = summaries
        self.tokenizer = tokenizer
        self.max_input_length = max_input_length
        self.max_target_length = max_target_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        summary = self.summaries[idx]

        encoded_inputs = self.tokenizer.encode_plus(
            "summarize: " + text,
            max_length=self.max_input_length,
            padding='max_length',
            truncation=True,
            return_tensors="pt"
        )
        input_ids = encoded_inputs['input_ids'].squeeze(0)
        attention_mask = encoded_inputs['attention_mask'].squeeze(0)

        labels = self.tokenizer.encode_plus(
            summary,
            max_length=self.max_target_length,
            padding='max_length',
            truncation=True,
            return_tensors="pt"
        )['input_ids'].squeeze(0)

        labels[labels == self.tokenizer.pad_token_id] = -100

        return {'input_ids': input_ids, 'attention_mask': attention_mask, 'labels': labels}

# %%
train_dataset = SummaryDataset(texts_list_train, summary_list_train, tokenizer, max_input_length, max_target_length)
val_dataset = SummaryDataset(texts_list_val, summary_list_val, tokenizer, max_input_length, max_target_length)
test_dataset = SummaryDataset(texts_list_test, summary_list_test, tokenizer, max_input_length, max_target_length)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(20100, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(20100, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(20100, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=512, out_features=20100, bias=False)
# )

# %%
optimizer = AdamW(model.parameters(), lr=learning_rate)
total_steps = len(train_loader) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)
# Out:
# C:\Users\inact1ve\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\optimization.py:521: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
rouge = load_metric('rouge')
writer = SummaryWriter(log_dir='logs_model')
# Out:
# C:\Users\inact1ve\AppData\Local\Temp\ipykernel_7576\2844806384.py:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric('rouge')
# C:\Users\inact1ve\AppData\Local\Programs\Python\Python312\Lib\site-packages\datasets\load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.1/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(

# %%
for epoch in range(epochs):
    model.train()
    total_loss = 0

    for batch_idx, batch in enumerate(train_loader):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        optimizer.zero_grad()
        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_loss += loss.item()

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        writer.add_scalar('Train/Loss', loss.item(), epoch * len(train_loader) + batch_idx)

    avg_train_loss = total_loss / len(train_loader)
    print(f'Epoch {epoch + 1}/{epochs}, Loss: {avg_train_loss}')
    try:
        model.eval()
        total_val_loss = 0
        val_outputs = []
        val_labels = []

        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)

                outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
                loss = outputs.loss
                total_val_loss += loss.item()

                generated_ids = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=max_target_length, num_beams=4)
                val_outputs.extend([tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in generated_ids])
                decoded_labels = []
                for l in labels:
                    l = l[l != -100]
                    decoded_labels.append(tokenizer.decode(l, skip_special_tokens=True, clean_up_tokenization_spaces=False))

                val_labels.extend(decoded_labels)

        avg_val_loss = total_val_loss / len(val_loader)
        print(f'Validation Loss: {avg_val_loss}')

        writer.add_scalar('Validation/Loss', avg_val_loss, epoch)

        rouge_result = rouge.compute(predictions=val_outputs, references=val_labels)
        print(f'ROUGE-1: {rouge_result["rouge1"].mid.fmeasure:.4f}, ROUGE-2: {rouge_result["rouge2"].mid.fmeasure:.4f}, ROUGE-L: {rouge_result["rougeL"].mid.fmeasure:.4f}')

        writer.add_scalar('Validation/ROUGE-1', rouge_result["rouge1"].mid.fmeasure, epoch)
        writer.add_scalar('Validation/ROUGE-2', rouge_result["rouge2"].mid.fmeasure, epoch)
        writer.add_scalar('Validation/ROUGE-L', rouge_result["rougeL"].mid.fmeasure, epoch)
    except:
        print("Fail validation")

writer.close()
model.save_pretrained("val_trained_model")
tokenizer.save_pretrained("val_tokenizer")
# Out:
# Epoch 1/5, Loss: 2.792672300893842
# Validation Loss: 2.120660104259181
# ROUGE-1: 0.1637, ROUGE-2: 0.0392, ROUGE-L: 0.1602
# Epoch 2/5, Loss: 2.61161929162404
# Validation Loss: 2.0827244753718106
# ROUGE-1: 0.1736, ROUGE-2: 0.0434, ROUGE-L: 0.1698
# Epoch 3/5, Loss: 2.549147611774561
# Validation Loss: 2.0509361693962287
# ROUGE-1: 0.1751, ROUGE-2: 0.0442, ROUGE-L: 0.1709
# Epoch 4/5, Loss: 2.5137982921745943
# Validation Loss: 2.0382783048154733
# ROUGE-1: 0.1777, ROUGE-2: 0.0441, ROUGE-L: 0.1733
# Epoch 5/5, Loss: 2.4970993428011887
# Validation Loss: 2.0365842202439306
# ROUGE-1: 0.1772, ROUGE-2: 0.0444, ROUGE-L: 0.1734
# ('val_tokenizer\\tokenizer_config.json',
#  'val_tokenizer\\special_tokens_map.json',
#  'val_tokenizer\\spiece.model',
#  'val_tokenizer\\added_tokens.json')

# %%
model.save_pretrained("df_trained_model")

# %%
def summarize_text(model, tokenizer, text, device, max_input_length=9559, max_output_length=554, num_beams=4):
    model.to(device)
    model.eval()

    inputs = tokenizer.encode_plus(
        text,
        return_tensors='pt',
        max_length=max_input_length,
        truncation=True,
        padding='max_length'
    )

    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)

    with torch.no_grad():
        summary_ids = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_length=max_output_length,
            num_beams=num_beams,
            length_penalty=2.0,
            early_stopping=True
        )

    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True, clean_up_tokenization_spaces=False)

    return summary

# %%
text = texts_list_test[15]
summarized_text = summarize_text(model, tokenizer, text, device)

# %%
len(max(texts_list_test, key=len))
# Out:
# 9559

# %%
len(max(summary_list_test, key=len))
# Out:
# 554

# %%
summary_result_test = []

# %%
for i in range(0, len(texts_list_test)):
    print(f"text {i} in {len(texts_list_test)} texts")
    summary_result = summarize_text(model, tokenizer, texts_list_test[i], device)
    summary_result_test.append(summary_result)
# Out:
# text 0 in 5770 texts
# text 1 in 5770 texts
# text 2 in 5770 texts
# text 3 in 5770 texts
# text 4 in 5770 texts
# text 5 in 5770 texts
# text 6 in 5770 texts
# text 7 in 5770 texts
# text 8 in 5770 texts
# text 9 in 5770 texts
# text 10 in 5770 texts
# text 11 in 5770 texts
# text 12 in 5770 texts
# text 13 in 5770 texts
# text 14 in 5770 texts
# text 15 in 5770 texts
# text 16 in 5770 texts
# text 17 in 5770 texts
# text 18 in 5770 texts
# text 19 in 5770 texts
# text 20 in 5770 texts
# text 21 in 5770 texts
# text 22 in 5770 texts
# text 23 in 5770 texts
# text 24 in 5770 texts
# text 25 in 5770 texts
# text 26 in 5770 texts
# text 27 in 5770 texts
# text 28 in 5770 texts
# text 29 in 5770 texts
# text 30 in 5770 texts
# text 31 in 5770 texts
# text 32 in 5770 texts
# text 33 in 5770 texts
# text 34 in 5770 texts
# text 35 in 5770 texts
# text 36 in 5770 texts
# text 37 in 5770 texts
# text 38 in 5770 texts
# text 39 in 5770 texts
# text 40 in 5770 texts
# text 41 in 5770 texts
# text 42 in 5770 texts
# text 43 in 5770 texts
# text 44 in 5770 texts
# text 45 in 5770 texts
# text 46 in 5770 texts
# text 47 in 5770 texts
# text 48 in 5770 texts
# text 49 in 5770 texts
# text 50 in 5770 texts
# text 51 in 5770 texts
# text 52 in 5770 texts
# text 53 in 5770 texts
# text 54 in 5770 texts
# text 55 in 5770 texts
# text 56 in 5770 texts
# text 57 in 5770 texts
# text 58 in 5770 texts
# text 59 in 5770 texts
# text 60 in 5770 texts
# text 61 in 5770 texts
# text 62 in 5770 texts
# text 63 in 5770 texts
# text 64 in 5770 texts
# text 65 in 5770 texts
# text 66 in 5770 texts
# text 67 in 5770 texts
# text 68 in 5770 texts
# text 69 in 5770 texts
# text 70 in 5770 texts
# text 71 in 5770 texts
# text 72 in 5770 texts
# text 73 in 5770 texts
# text 74 in 5770 texts
# text 75 in 5770 texts
# text 76 in 5770 texts
# text 77 in 5770 texts
# text 78 in 5770 texts
# text 79 in 5770 texts
# text 80 in 5770 texts
# text 81 in 5770 texts
# text 82 in 5770 texts
# text 83 in 5770 texts
# text 84 in 5770 texts
# text 85 in 5770 texts
# text 86 in 5770 texts
# text 87 in 5770 texts
# text 88 in 5770 texts
# text 89 in 5770 texts
# text 90 in 5770 texts
# text 91 in 5770 texts
# text 92 in 5770 texts
# text 93 in 5770 texts
# text 94 in 5770 texts
# text 95 in 5770 texts
# text 96 in 5770 texts
# text 97 in 5770 texts
# text 98 in 5770 texts
# text 99 in 5770 texts
# text 100 in 5770 texts
# text 101 in 5770 texts
# text 102 in 5770 texts
# text 103 in 5770 texts
# text 104 in 5770 texts
# text 105 in 5770 texts
# text 106 in 5770 texts
# text 107 in 5770 texts
# text 108 in 5770 texts
# text 109 in 5770 texts
# text 110 in 5770 texts
# text 111 in 5770 texts
# text 112 in 5770 texts
# text 113 in 5770 texts
# text 114 in 5770 texts
# text 115 in 5770 texts
# text 116 in 5770 texts
# text 117 in 5770 texts
# text 118 in 5770 texts
# text 119 in 5770 texts
# text 120 in 5770 texts
# text 121 in 5770 texts
# text 122 in 5770 texts
# text 123 in 5770 texts
# text 124 in 5770 texts
# text 125 in 5770 texts
# text 126 in 5770 texts
# text 127 in 5770 texts
# text 128 in 5770 texts
# text 129 in 5770 texts
# text 130 in 5770 texts
# text 131 in 5770 texts
# text 132 in 5770 texts
# text 133 in 5770 texts
# text 134 in 5770 texts
# text 135 in 5770 texts
# text 136 in 5770 texts
# text 137 in 5770 texts
# text 138 in 5770 texts
# text 139 in 5770 texts
# text 140 in 5770 texts
# text 141 in 5770 texts
# text 142 in 5770 texts
# text 143 in 5770 texts
# text 144 in 5770 texts
# text 145 in 5770 texts
# text 146 in 5770 texts
# text 147 in 5770 texts
# text 148 in 5770 texts
# text 149 in 5770 texts
# text 150 in 5770 texts
# text 151 in 5770 texts
# text 152 in 5770 texts
# text 153 in 5770 texts
# text 154 in 5770 texts
# text 155 in 5770 texts
# text 156 in 5770 texts
# text 157 in 5770 texts
# text 158 in 5770 texts
# text 159 in 5770 texts
# text 160 in 5770 texts
# text 161 in 5770 texts
# text 162 in 5770 texts
# text 163 in 5770 texts
# text 164 in 5770 texts
# text 165 in 5770 texts
# text 166 in 5770 texts
# text 167 in 5770 texts
# text 168 in 5770 texts
# text 169 in 5770 texts
# text 170 in 5770 texts
# text 171 in 5770 texts
# text 172 in 5770 texts
# text 173 in 5770 texts
# text 174 in 5770 texts
# text 175 in 5770 texts
# text 176 in 5770 texts
# text 177 in 5770 texts
# text 178 in 5770 texts
# text 179 in 5770 texts
# text 180 in 5770 texts
# text 181 in 5770 texts
# text 182 in 5770 texts
# text 183 in 5770 texts
# text 184 in 5770 texts
# text 185 in 5770 texts
# text 186 in 5770 texts
# text 187 in 5770 texts
# text 188 in 5770 texts
# text 189 in 5770 texts
# text 190 in 5770 texts
# text 191 in 5770 texts
# text 192 in 5770 texts
# text 193 in 5770 texts
# text 194 in 5770 texts
# text 195 in 5770 texts
# text 196 in 5770 texts
# text 197 in 5770 texts
# text 198 in 5770 texts
# text 199 in 5770 texts
# text 200 in 5770 texts
# text 201 in 5770 texts
# text 202 in 5770 texts
# text 203 in 5770 texts
# text 204 in 5770 texts
# text 205 in 5770 texts
# text 206 in 5770 texts
# text 207 in 5770 texts
# text 208 in 5770 texts
# text 209 in 5770 texts
# text 210 in 5770 texts
# text 211 in 5770 texts
# text 212 in 5770 texts
# text 213 in 5770 texts
# text 214 in 5770 texts
# text 215 in 5770 texts
# text 216 in 5770 texts
# text 217 in 5770 texts
# text 218 in 5770 texts
# text 219 in 5770 texts
# text 220 in 5770 texts
# text 221 in 5770 texts
# text 222 in 5770 texts
# text 223 in 5770 texts
# text 224 in 5770 texts
# text 225 in 5770 texts
# text 226 in 5770 texts
# text 227 in 5770 texts
# text 228 in 5770 texts
# text 229 in 5770 texts
# text 230 in 5770 texts
# text 231 in 5770 texts
# text 232 in 5770 texts
# text 233 in 5770 texts
# text 234 in 5770 texts
# text 235 in 5770 texts
# text 236 in 5770 texts
# text 237 in 5770 texts
# text 238 in 5770 texts
# text 239 in 5770 texts
# text 240 in 5770 texts
# text 241 in 5770 texts
# text 242 in 5770 texts
# text 243 in 5770 texts
# text 244 in 5770 texts
# text 245 in 5770 texts
# text 246 in 5770 texts
# text 247 in 5770 texts
# text 248 in 5770 texts
# text 249 in 5770 texts
# text 250 in 5770 texts
# text 251 in 5770 texts
# text 252 in 5770 texts
# text 253 in 5770 texts
# text 254 in 5770 texts
# text 255 in 5770 texts
# text 256 in 5770 texts
# text 257 in 5770 texts
# text 258 in 5770 texts
# text 259 in 5770 texts
# text 260 in 5770 texts
# text 261 in 5770 texts
# text 262 in 5770 texts
# text 263 in 5770 texts
# text 264 in 5770 texts
# text 265 in 5770 texts
# text 266 in 5770 texts
# text 267 in 5770 texts
# text 268 in 5770 texts
# text 269 in 5770 texts
# text 270 in 5770 texts
# text 271 in 5770 texts
# text 272 in 5770 texts
# text 273 in 5770 texts
# text 274 in 5770 texts
# text 275 in 5770 texts
# text 276 in 5770 texts
# text 277 in 5770 texts
# text 278 in 5770 texts
# text 279 in 5770 texts
# text 280 in 5770 texts
# text 281 in 5770 texts
# text 282 in 5770 texts
# text 283 in 5770 texts
# text 284 in 5770 texts
# text 285 in 5770 texts
# text 286 in 5770 texts
# text 287 in 5770 texts
# text 288 in 5770 texts
# text 289 in 5770 texts
# text 290 in 5770 texts
# text 291 in 5770 texts
# text 292 in 5770 texts
# text 293 in 5770 texts
# text 294 in 5770 texts
# text 295 in 5770 texts
# text 296 in 5770 texts
# text 297 in 5770 texts
# text 298 in 5770 texts
# text 299 in 5770 texts
# text 300 in 5770 texts
# text 301 in 5770 texts
# text 302 in 5770 texts
# text 303 in 5770 texts
# text 304 in 5770 texts
# text 305 in 5770 texts
# text 306 in 5770 texts
# text 307 in 5770 texts
# text 308 in 5770 texts
# text 309 in 5770 texts
# text 310 in 5770 texts
# text 311 in 5770 texts
# text 312 in 5770 texts
# text 313 in 5770 texts
# text 314 in 5770 texts
# text 315 in 5770 texts
# text 316 in 5770 texts
# text 317 in 5770 texts
# text 318 in 5770 texts
# text 319 in 5770 texts
# text 320 in 5770 texts
# text 321 in 5770 texts
# text 322 in 5770 texts
# text 323 in 5770 texts
# text 324 in 5770 texts
# text 325 in 5770 texts
# text 326 in 5770 texts
# text 327 in 5770 texts
# text 328 in 5770 texts
# text 329 in 5770 texts
# text 330 in 5770 texts
# text 331 in 5770 texts
# text 332 in 5770 texts
# text 333 in 5770 texts
# text 334 in 5770 texts
# text 335 in 5770 texts
# text 336 in 5770 texts
# text 337 in 5770 texts
# text 338 in 5770 texts
# text 339 in 5770 texts
# text 340 in 5770 texts
# text 341 in 5770 texts
# text 342 in 5770 texts
# text 343 in 5770 texts
# text 344 in 5770 texts
# text 345 in 5770 texts
# text 346 in 5770 texts
# text 347 in 5770 texts
# text 348 in 5770 texts
# text 349 in 5770 texts
# text 350 in 5770 texts
# text 351 in 5770 texts
# text 352 in 5770 texts
# text 353 in 5770 texts
# text 354 in 5770 texts
# text 355 in 5770 texts
# text 356 in 5770 texts
# text 357 in 5770 texts
# text 358 in 5770 texts
# text 359 in 5770 texts
# text 360 in 5770 texts
# text 361 in 5770 texts
# text 362 in 5770 texts
# text 363 in 5770 texts
# text 364 in 5770 texts
# text 365 in 5770 texts
# text 366 in 5770 texts
# text 367 in 5770 texts
# text 368 in 5770 texts
# text 369 in 5770 texts
# text 370 in 5770 texts
# text 371 in 5770 texts
# text 372 in 5770 texts
# text 373 in 5770 texts
# text 374 in 5770 texts
# text 375 in 5770 texts
# text 376 in 5770 texts
# text 377 in 5770 texts
# text 378 in 5770 texts
# text 379 in 5770 texts
# text 380 in 5770 texts
# text 381 in 5770 texts
# text 382 in 5770 texts
# text 383 in 5770 texts
# text 384 in 5770 texts
# text 385 in 5770 texts
# text 386 in 5770 texts
# text 387 in 5770 texts
# text 388 in 5770 texts
# text 389 in 5770 texts
# text 390 in 5770 texts
# text 391 in 5770 texts
# text 392 in 5770 texts
# text 393 in 5770 texts
# text 394 in 5770 texts
# text 395 in 5770 texts
# text 396 in 5770 texts
# text 397 in 5770 texts
# text 398 in 5770 texts
# text 399 in 5770 texts
# text 400 in 5770 texts
# text 401 in 5770 texts
# text 402 in 5770 texts
# text 403 in 5770 texts
# text 404 in 5770 texts
# text 405 in 5770 texts
# text 406 in 5770 texts
# text 407 in 5770 texts
# text 408 in 5770 texts
# text 409 in 5770 texts
# text 410 in 5770 texts
# text 411 in 5770 texts
# text 412 in 5770 texts
# text 413 in 5770 texts
# text 414 in 5770 texts
# text 415 in 5770 texts
# text 416 in 5770 texts
# text 417 in 5770 texts
# text 418 in 5770 texts
# text 419 in 5770 texts
# text 420 in 5770 texts
# text 421 in 5770 texts
# text 422 in 5770 texts
# text 423 in 5770 texts
# text 424 in 5770 texts
# text 425 in 5770 texts
# text 426 in 5770 texts
# text 427 in 5770 texts
# text 428 in 5770 texts
# text 429 in 5770 texts
# text 430 in 5770 texts
# text 431 in 5770 texts
# text 432 in 5770 texts
# text 433 in 5770 texts
# text 434 in 5770 texts
# text 435 in 5770 texts
# text 436 in 5770 texts
# text 437 in 5770 texts
# text 438 in 5770 texts
# text 439 in 5770 texts
# text 440 in 5770 texts
# text 441 in 5770 texts
# text 442 in 5770 texts
# text 443 in 5770 texts
# text 444 in 5770 texts
# text 445 in 5770 texts
# text 446 in 5770 texts
# text 447 in 5770 texts
# text 448 in 5770 texts
# text 449 in 5770 texts
# text 450 in 5770 texts
# text 451 in 5770 texts
# text 452 in 5770 texts
# text 453 in 5770 texts
# text 454 in 5770 texts
# text 455 in 5770 texts
# text 456 in 5770 texts
# text 457 in 5770 texts
# text 458 in 5770 texts
# text 459 in 5770 texts
# text 460 in 5770 texts
# text 461 in 5770 texts
# text 462 in 5770 texts
# text 463 in 5770 texts
# text 464 in 5770 texts
# text 465 in 5770 texts
# text 466 in 5770 texts
# text 467 in 5770 texts
# text 468 in 5770 texts
# text 469 in 5770 texts
# text 470 in 5770 texts
# text 471 in 5770 texts
# text 472 in 5770 texts
# text 473 in 5770 texts
# text 474 in 5770 texts
# text 475 in 5770 texts
# text 476 in 5770 texts
# text 477 in 5770 texts
# text 478 in 5770 texts
# text 479 in 5770 texts
# text 480 in 5770 texts
# text 481 in 5770 texts
# text 482 in 5770 texts
# text 483 in 5770 texts
# text 484 in 5770 texts
# text 485 in 5770 texts
# text 486 in 5770 texts
# text 487 in 5770 texts
# text 488 in 5770 texts
# text 489 in 5770 texts
# text 490 in 5770 texts
# text 491 in 5770 texts
# text 492 in 5770 texts
# text 493 in 5770 texts
# text 494 in 5770 texts
# text 495 in 5770 texts
# text 496 in 5770 texts
# text 497 in 5770 texts
# text 498 in 5770 texts
# text 499 in 5770 texts
# text 500 in 5770 texts
# text 501 in 5770 texts
# text 502 in 5770 texts
# text 503 in 5770 texts
# text 504 in 5770 texts
# text 505 in 5770 texts
# text 506 in 5770 texts
# text 507 in 5770 texts
# text 508 in 5770 texts
# text 509 in 5770 texts
# text 510 in 5770 texts
# text 511 in 5770 texts
# text 512 in 5770 texts
# text 513 in 5770 texts
# text 514 in 5770 texts
# text 515 in 5770 texts
# text 516 in 5770 texts
# text 517 in 5770 texts
# text 518 in 5770 texts
# text 519 in 5770 texts
# text 520 in 5770 texts
# text 521 in 5770 texts
# text 522 in 5770 texts
# text 523 in 5770 texts
# text 524 in 5770 texts
# text 525 in 5770 texts
# text 526 in 5770 texts
# text 527 in 5770 texts
# text 528 in 5770 texts
# text 529 in 5770 texts
# text 530 in 5770 texts
# text 531 in 5770 texts
# text 532 in 5770 texts
# text 533 in 5770 texts
# text 534 in 5770 texts
# text 535 in 5770 texts
# text 536 in 5770 texts
# text 537 in 5770 texts
# text 538 in 5770 texts
# text 539 in 5770 texts
# text 540 in 5770 texts
# text 541 in 5770 texts
# text 542 in 5770 texts
# text 543 in 5770 texts
# text 544 in 5770 texts
# text 545 in 5770 texts
# text 546 in 5770 texts
# text 547 in 5770 texts
# text 548 in 5770 texts
# text 549 in 5770 texts
# text 550 in 5770 texts
# text 551 in 5770 texts
# text 552 in 5770 texts
# text 553 in 5770 texts
# text 554 in 5770 texts
# text 555 in 5770 texts
# text 556 in 5770 texts
# text 557 in 5770 texts
# text 558 in 5770 texts
# text 559 in 5770 texts
# text 560 in 5770 texts
# text 561 in 5770 texts
# text 562 in 5770 texts
# text 563 in 5770 texts
# text 564 in 5770 texts
# text 565 in 5770 texts
# text 566 in 5770 texts
# text 567 in 5770 texts
# text 568 in 5770 texts
# text 569 in 5770 texts
# text 570 in 5770 texts
# text 571 in 5770 texts
# text 572 in 5770 texts
# text 573 in 5770 texts
# text 574 in 5770 texts
# text 575 in 5770 texts
# text 576 in 5770 texts
# text 577 in 5770 texts
# text 578 in 5770 texts
# text 579 in 5770 texts
# text 580 in 5770 texts
# text 581 in 5770 texts
# text 582 in 5770 texts
# text 583 in 5770 texts
# text 584 in 5770 texts
# text 585 in 5770 texts
# text 586 in 5770 texts
# text 587 in 5770 texts
# text 588 in 5770 texts
# text 589 in 5770 texts
# text 590 in 5770 texts
# text 591 in 5770 texts
# text 592 in 5770 texts
# text 593 in 5770 texts
# text 594 in 5770 texts
# text 595 in 5770 texts
# text 596 in 5770 texts
# text 597 in 5770 texts
# text 598 in 5770 texts
# text 599 in 5770 texts
# text 600 in 5770 texts
# text 601 in 5770 texts
# text 602 in 5770 texts
# text 603 in 5770 texts
# text 604 in 5770 texts
# text 605 in 5770 texts
# text 606 in 5770 texts
# text 607 in 5770 texts
# text 608 in 5770 texts
# text 609 in 5770 texts
# text 610 in 5770 texts
# text 611 in 5770 texts
# text 612 in 5770 texts
# text 613 in 5770 texts
# text 614 in 5770 texts
# text 615 in 5770 texts
# text 616 in 5770 texts
# text 617 in 5770 texts
# text 618 in 5770 texts
# text 619 in 5770 texts
# text 620 in 5770 texts
# text 621 in 5770 texts
# text 622 in 5770 texts
# text 623 in 5770 texts
# text 624 in 5770 texts
# text 625 in 5770 texts
# text 626 in 5770 texts
# text 627 in 5770 texts
# text 628 in 5770 texts
# text 629 in 5770 texts
# text 630 in 5770 texts
# text 631 in 5770 texts
# text 632 in 5770 texts
# text 633 in 5770 texts
# text 634 in 5770 texts
# text 635 in 5770 texts
# text 636 in 5770 texts
# text 637 in 5770 texts
# text 638 in 5770 texts
# text 639 in 5770 texts
# text 640 in 5770 texts
# text 641 in 5770 texts
# text 642 in 5770 texts
# text 643 in 5770 texts
# text 644 in 5770 texts
# text 645 in 5770 texts
# text 646 in 5770 texts
# text 647 in 5770 texts
# text 648 in 5770 texts
# text 649 in 5770 texts
# text 650 in 5770 texts
# text 651 in 5770 texts
# text 652 in 5770 texts
# text 653 in 5770 texts
# text 654 in 5770 texts
# text 655 in 5770 texts
# text 656 in 5770 texts
# text 657 in 5770 texts
# text 658 in 5770 texts
# text 659 in 5770 texts
# text 660 in 5770 texts
# text 661 in 5770 texts
# text 662 in 5770 texts
# text 663 in 5770 texts
# text 664 in 5770 texts
# text 665 in 5770 texts
# text 666 in 5770 texts
# text 667 in 5770 texts
# text 668 in 5770 texts
# text 669 in 5770 texts
# text 670 in 5770 texts
# text 671 in 5770 texts
# text 672 in 5770 texts
# text 673 in 5770 texts
# text 674 in 5770 texts
# text 675 in 5770 texts
# text 676 in 5770 texts
# text 677 in 5770 texts
# text 678 in 5770 texts
# text 679 in 5770 texts
# text 680 in 5770 texts
# text 681 in 5770 texts
# text 682 in 5770 texts
# text 683 in 5770 texts
# text 684 in 5770 texts
# text 685 in 5770 texts
# text 686 in 5770 texts
# text 687 in 5770 texts
# text 688 in 5770 texts
# text 689 in 5770 texts
# text 690 in 5770 texts
# text 691 in 5770 texts
# text 692 in 5770 texts
# text 693 in 5770 texts
# text 694 in 5770 texts
# text 695 in 5770 texts
# text 696 in 5770 texts
# text 697 in 5770 texts
# text 698 in 5770 texts
# text 699 in 5770 texts
# text 700 in 5770 texts
# text 701 in 5770 texts
# text 702 in 5770 texts
# text 703 in 5770 texts
# text 704 in 5770 texts
# text 705 in 5770 texts
# text 706 in 5770 texts
# text 707 in 5770 texts
# text 708 in 5770 texts
# text 709 in 5770 texts
# text 710 in 5770 texts
# text 711 in 5770 texts
# text 712 in 5770 texts
# text 713 in 5770 texts
# text 714 in 5770 texts
# text 715 in 5770 texts
# text 716 in 5770 texts
# text 717 in 5770 texts
# text 718 in 5770 texts
# text 719 in 5770 texts
# text 720 in 5770 texts
# text 721 in 5770 texts
# text 722 in 5770 texts
# text 723 in 5770 texts
# text 724 in 5770 texts
# text 725 in 5770 texts
# text 726 in 5770 texts
# text 727 in 5770 texts
# text 728 in 5770 texts
# text 729 in 5770 texts
# text 730 in 5770 texts
# text 731 in 5770 texts
# text 732 in 5770 texts
# text 733 in 5770 texts
# text 734 in 5770 texts
# text 735 in 5770 texts
# text 736 in 5770 texts
# text 737 in 5770 texts
# text 738 in 5770 texts
# text 739 in 5770 texts
# text 740 in 5770 texts
# text 741 in 5770 texts
# text 742 in 5770 texts
# text 743 in 5770 texts
# text 744 in 5770 texts
# text 745 in 5770 texts
# text 746 in 5770 texts
# text 747 in 5770 texts
# text 748 in 5770 texts
# text 749 in 5770 texts
# text 750 in 5770 texts
# text 751 in 5770 texts
# text 752 in 5770 texts
# text 753 in 5770 texts
# text 754 in 5770 texts
# text 755 in 5770 texts
# text 756 in 5770 texts
# text 757 in 5770 texts
# text 758 in 5770 texts
# text 759 in 5770 texts
# text 760 in 5770 texts
# text 761 in 5770 texts
# text 762 in 5770 texts
# text 763 in 5770 texts
# text 764 in 5770 texts
# text 765 in 5770 texts
# text 766 in 5770 texts
# text 767 in 5770 texts
# text 768 in 5770 texts
# text 769 in 5770 texts
# text 770 in 5770 texts
# text 771 in 5770 texts
# text 772 in 5770 texts
# text 773 in 5770 texts
# text 774 in 5770 texts
# text 775 in 5770 texts
# text 776 in 5770 texts
# text 777 in 5770 texts
# text 778 in 5770 texts
# text 779 in 5770 texts
# text 780 in 5770 texts
# text 781 in 5770 texts
# text 782 in 5770 texts
# text 783 in 5770 texts
# text 784 in 5770 texts
# text 785 in 5770 texts
# text 786 in 5770 texts
# text 787 in 5770 texts
# text 788 in 5770 texts
# text 789 in 5770 texts
# text 790 in 5770 texts
# text 791 in 5770 texts
# text 792 in 5770 texts
# text 793 in 5770 texts
# text 794 in 5770 texts
# text 795 in 5770 texts
# text 796 in 5770 texts
# text 797 in 5770 texts
# text 798 in 5770 texts
# text 799 in 5770 texts
# text 800 in 5770 texts
# text 801 in 5770 texts
# text 802 in 5770 texts
# text 803 in 5770 texts
# text 804 in 5770 texts
# text 805 in 5770 texts
# text 806 in 5770 texts
# text 807 in 5770 texts
# text 808 in 5770 texts
# text 809 in 5770 texts
# text 810 in 5770 texts
# text 811 in 5770 texts
# text 812 in 5770 texts
# text 813 in 5770 texts
# text 814 in 5770 texts
# text 815 in 5770 texts
# text 816 in 5770 texts
# text 817 in 5770 texts
# text 818 in 5770 texts
# text 819 in 5770 texts
# text 820 in 5770 texts
# text 821 in 5770 texts
# text 822 in 5770 texts
# text 823 in 5770 texts
# text 824 in 5770 texts
# text 825 in 5770 texts
# text 826 in 5770 texts
# text 827 in 5770 texts
# text 828 in 5770 texts
# text 829 in 5770 texts
# text 830 in 5770 texts
# text 831 in 5770 texts
# text 832 in 5770 texts
# text 833 in 5770 texts
# text 834 in 5770 texts
# text 835 in 5770 texts
# text 836 in 5770 texts
# text 837 in 5770 texts
# text 838 in 5770 texts
# text 839 in 5770 texts
# text 840 in 5770 texts
# text 841 in 5770 texts
# text 842 in 5770 texts
# text 843 in 5770 texts
# text 844 in 5770 texts
# text 845 in 5770 texts
# text 846 in 5770 texts
# text 847 in 5770 texts
# text 848 in 5770 texts
# text 849 in 5770 texts
# text 850 in 5770 texts
# text 851 in 5770 texts
# text 852 in 5770 texts
# text 853 in 5770 texts
# text 854 in 5770 texts
# text 855 in 5770 texts
# text 856 in 5770 texts
# text 857 in 5770 texts
# text 858 in 5770 texts
# text 859 in 5770 texts
# text 860 in 5770 texts
# text 861 in 5770 texts
# text 862 in 5770 texts
# text 863 in 5770 texts
# text 864 in 5770 texts
# text 865 in 5770 texts
# text 866 in 5770 texts
# text 867 in 5770 texts
# text 868 in 5770 texts
# text 869 in 5770 texts
# text 870 in 5770 texts
# text 871 in 5770 texts
# text 872 in 5770 texts
# text 873 in 5770 texts
# text 874 in 5770 texts
# text 875 in 5770 texts
# text 876 in 5770 texts
# text 877 in 5770 texts
# text 878 in 5770 texts
# text 879 in 5770 texts
# text 880 in 5770 texts
# text 881 in 5770 texts
# text 882 in 5770 texts
# text 883 in 5770 texts
# text 884 in 5770 texts
# text 885 in 5770 texts
# text 886 in 5770 texts
# text 887 in 5770 texts
# text 888 in 5770 texts
# text 889 in 5770 texts
# text 890 in 5770 texts
# text 891 in 5770 texts
# text 892 in 5770 texts
# text 893 in 5770 texts
# text 894 in 5770 texts
# text 895 in 5770 texts
# text 896 in 5770 texts
# text 897 in 5770 texts
# text 898 in 5770 texts
# text 899 in 5770 texts
# text 900 in 5770 texts
# text 901 in 5770 texts
# text 902 in 5770 texts
# text 903 in 5770 texts
# text 904 in 5770 texts
# text 905 in 5770 texts
# text 906 in 5770 texts
# text 907 in 5770 texts
# text 908 in 5770 texts
# text 909 in 5770 texts
# text 910 in 5770 texts
# text 911 in 5770 texts
# text 912 in 5770 texts
# text 913 in 5770 texts
# text 914 in 5770 texts
# text 915 in 5770 texts
# text 916 in 5770 texts
# text 917 in 5770 texts
# text 918 in 5770 texts
# text 919 in 5770 texts
# text 920 in 5770 texts
# text 921 in 5770 texts
# text 922 in 5770 texts
# text 923 in 5770 texts
# text 924 in 5770 texts
# text 925 in 5770 texts
# text 926 in 5770 texts
# text 927 in 5770 texts
# text 928 in 5770 texts
# text 929 in 5770 texts
# text 930 in 5770 texts
# text 931 in 5770 texts
# text 932 in 5770 texts
# text 933 in 5770 texts
# text 934 in 5770 texts
# text 935 in 5770 texts
# text 936 in 5770 texts
# text 937 in 5770 texts
# text 938 in 5770 texts
# text 939 in 5770 texts
# text 940 in 5770 texts
# text 941 in 5770 texts
# text 942 in 5770 texts
# text 943 in 5770 texts
# text 944 in 5770 texts
# text 945 in 5770 texts
# text 946 in 5770 texts
# text 947 in 5770 texts
# text 948 in 5770 texts
# text 949 in 5770 texts
# text 950 in 5770 texts
# text 951 in 5770 texts
# text 952 in 5770 texts
# text 953 in 5770 texts
# text 954 in 5770 texts
# text 955 in 5770 texts
# text 956 in 5770 texts
# text 957 in 5770 texts
# text 958 in 5770 texts
# text 959 in 5770 texts
# text 960 in 5770 texts
# text 961 in 5770 texts
# text 962 in 5770 texts
# text 963 in 5770 texts
# text 964 in 5770 texts
# text 965 in 5770 texts
# text 966 in 5770 texts
# text 967 in 5770 texts
# text 968 in 5770 texts
# text 969 in 5770 texts
# text 970 in 5770 texts
# text 971 in 5770 texts
# text 972 in 5770 texts
# text 973 in 5770 texts
# text 974 in 5770 texts
# text 975 in 5770 texts
# text 976 in 5770 texts
# text 977 in 5770 texts
# text 978 in 5770 texts
# text 979 in 5770 texts
# text 980 in 5770 texts
# text 981 in 5770 texts
# text 982 in 5770 texts
# text 983 in 5770 texts
# text 984 in 5770 texts
# text 985 in 5770 texts
# text 986 in 5770 texts
# text 987 in 5770 texts
# text 988 in 5770 texts
# text 989 in 5770 texts
# text 990 in 5770 texts
# text 991 in 5770 texts
# text 992 in 5770 texts
# text 993 in 5770 texts
# text 994 in 5770 texts
# text 995 in 5770 texts
# text 996 in 5770 texts
# text 997 in 5770 texts
# text 998 in 5770 texts
# text 999 in 5770 texts
# text 1000 in 5770 texts
# text 1001 in 5770 texts
# text 1002 in 5770 texts
# text 1003 in 5770 texts
# text 1004 in 5770 texts
# text 1005 in 5770 texts
# text 1006 in 5770 texts
# text 1007 in 5770 texts
# text 1008 in 5770 texts
# text 1009 in 5770 texts
# text 1010 in 5770 texts
# text 1011 in 5770 texts
# text 1012 in 5770 texts
# text 1013 in 5770 texts
# text 1014 in 5770 texts
# text 1015 in 5770 texts
# text 1016 in 5770 texts
# text 1017 in 5770 texts
# text 1018 in 5770 texts
# text 1019 in 5770 texts
# text 1020 in 5770 texts
# text 1021 in 5770 texts
# text 1022 in 5770 texts
# text 1023 in 5770 texts
# text 1024 in 5770 texts
# text 1025 in 5770 texts
# text 1026 in 5770 texts
# text 1027 in 5770 texts
# text 1028 in 5770 texts
# text 1029 in 5770 texts
# text 1030 in 5770 texts
# text 1031 in 5770 texts
# text 1032 in 5770 texts
# text 1033 in 5770 texts
# text 1034 in 5770 texts
# text 1035 in 5770 texts
# text 1036 in 5770 texts
# text 1037 in 5770 texts
# text 1038 in 5770 texts
# text 1039 in 5770 texts
# text 1040 in 5770 texts
# text 1041 in 5770 texts
# text 1042 in 5770 texts
# text 1043 in 5770 texts
# text 1044 in 5770 texts
# text 1045 in 5770 texts
# text 1046 in 5770 texts
# text 1047 in 5770 texts
# text 1048 in 5770 texts
# text 1049 in 5770 texts
# text 1050 in 5770 texts
# text 1051 in 5770 texts
# text 1052 in 5770 texts
# text 1053 in 5770 texts
# text 1054 in 5770 texts
# text 1055 in 5770 texts
# text 1056 in 5770 texts
# text 1057 in 5770 texts
# text 1058 in 5770 texts
# text 1059 in 5770 texts
# text 1060 in 5770 texts
# text 1061 in 5770 texts
# text 1062 in 5770 texts
# text 1063 in 5770 texts
# text 1064 in 5770 texts
# text 1065 in 5770 texts
# text 1066 in 5770 texts
# text 1067 in 5770 texts
# text 1068 in 5770 texts
# text 1069 in 5770 texts
# text 1070 in 5770 texts
# text 1071 in 5770 texts
# text 1072 in 5770 texts
# text 1073 in 5770 texts
# text 1074 in 5770 texts
# text 1075 in 5770 texts
# text 1076 in 5770 texts
# text 1077 in 5770 texts
# text 1078 in 5770 texts
# text 1079 in 5770 texts
# text 1080 in 5770 texts
# text 1081 in 5770 texts
# text 1082 in 5770 texts
# text 1083 in 5770 texts
# text 1084 in 5770 texts
# text 1085 in 5770 texts
# text 1086 in 5770 texts
# text 1087 in 5770 texts
# text 1088 in 5770 texts
# text 1089 in 5770 texts
# text 1090 in 5770 texts
# text 1091 in 5770 texts
# text 1092 in 5770 texts
# text 1093 in 5770 texts
# text 1094 in 5770 texts
# text 1095 in 5770 texts
# text 1096 in 5770 texts
# text 1097 in 5770 texts
# text 1098 in 5770 texts
# text 1099 in 5770 texts
# text 1100 in 5770 texts
# text 1101 in 5770 texts
# text 1102 in 5770 texts
# text 1103 in 5770 texts
# text 1104 in 5770 texts
# text 1105 in 5770 texts
# text 1106 in 5770 texts
# text 1107 in 5770 texts
# text 1108 in 5770 texts
# text 1109 in 5770 texts
# text 1110 in 5770 texts
# text 1111 in 5770 texts
# text 1112 in 5770 texts
# text 1113 in 5770 texts
# text 1114 in 5770 texts
# text 1115 in 5770 texts
# text 1116 in 5770 texts
# text 1117 in 5770 texts
# text 1118 in 5770 texts
# text 1119 in 5770 texts
# text 1120 in 5770 texts
# text 1121 in 5770 texts
# text 1122 in 5770 texts
# text 1123 in 5770 texts
# text 1124 in 5770 texts
# text 1125 in 5770 texts
# text 1126 in 5770 texts
# text 1127 in 5770 texts
# text 1128 in 5770 texts
# text 1129 in 5770 texts
# text 1130 in 5770 texts
# text 1131 in 5770 texts
# text 1132 in 5770 texts
# text 1133 in 5770 texts
# text 1134 in 5770 texts
# text 1135 in 5770 texts
# text 1136 in 5770 texts
# text 1137 in 5770 texts
# text 1138 in 5770 texts
# text 1139 in 5770 texts
# text 1140 in 5770 texts
# text 1141 in 5770 texts
# text 1142 in 5770 texts
# text 1143 in 5770 texts
# text 1144 in 5770 texts
# text 1145 in 5770 texts
# text 1146 in 5770 texts
# text 1147 in 5770 texts
# text 1148 in 5770 texts
# text 1149 in 5770 texts
# text 1150 in 5770 texts
# text 1151 in 5770 texts
# text 1152 in 5770 texts
# text 1153 in 5770 texts
# text 1154 in 5770 texts
# text 1155 in 5770 texts
# text 1156 in 5770 texts
# text 1157 in 5770 texts
# text 1158 in 5770 texts
# text 1159 in 5770 texts
# text 1160 in 5770 texts
# text 1161 in 5770 texts
# text 1162 in 5770 texts
# text 1163 in 5770 texts
# text 1164 in 5770 texts
# text 1165 in 5770 texts
# text 1166 in 5770 texts
# text 1167 in 5770 texts
# text 1168 in 5770 texts
# text 1169 in 5770 texts
# text 1170 in 5770 texts
# text 1171 in 5770 texts
# text 1172 in 5770 texts
# text 1173 in 5770 texts
# text 1174 in 5770 texts
# text 1175 in 5770 texts
# text 1176 in 5770 texts
# text 1177 in 5770 texts
# text 1178 in 5770 texts
# text 1179 in 5770 texts
# text 1180 in 5770 texts
# text 1181 in 5770 texts
# text 1182 in 5770 texts
# text 1183 in 5770 texts
# text 1184 in 5770 texts
# text 1185 in 5770 texts
# text 1186 in 5770 texts
# text 1187 in 5770 texts
# text 1188 in 5770 texts
# text 1189 in 5770 texts
# text 1190 in 5770 texts
# text 1191 in 5770 texts
# text 1192 in 5770 texts
# text 1193 in 5770 texts
# text 1194 in 5770 texts
# text 1195 in 5770 texts
# text 1196 in 5770 texts
# text 1197 in 5770 texts
# text 1198 in 5770 texts
# text 1199 in 5770 texts
# text 1200 in 5770 texts
# text 1201 in 5770 texts
# text 1202 in 5770 texts
# text 1203 in 5770 texts
# text 1204 in 5770 texts
# text 1205 in 5770 texts
# text 1206 in 5770 texts
# text 1207 in 5770 texts
# text 1208 in 5770 texts
# text 1209 in 5770 texts
# text 1210 in 5770 texts
# text 1211 in 5770 texts
# text 1212 in 5770 texts
# text 1213 in 5770 texts
# text 1214 in 5770 texts
# text 1215 in 5770 texts
# text 1216 in 5770 texts
# text 1217 in 5770 texts
# text 1218 in 5770 texts
# text 1219 in 5770 texts
# text 1220 in 5770 texts
# text 1221 in 5770 texts
# text 1222 in 5770 texts
# text 1223 in 5770 texts
# text 1224 in 5770 texts
# text 1225 in 5770 texts
# text 1226 in 5770 texts
# text 1227 in 5770 texts
# text 1228 in 5770 texts
# text 1229 in 5770 texts
# text 1230 in 5770 texts
# text 1231 in 5770 texts
# text 1232 in 5770 texts
# text 1233 in 5770 texts
# text 1234 in 5770 texts
# text 1235 in 5770 texts
# text 1236 in 5770 texts
# text 1237 in 5770 texts
# text 1238 in 5770 texts
# text 1239 in 5770 texts
# text 1240 in 5770 texts
# text 1241 in 5770 texts
# text 1242 in 5770 texts
# text 1243 in 5770 texts
# text 1244 in 5770 texts
# text 1245 in 5770 texts
# text 1246 in 5770 texts
# text 1247 in 5770 texts
# text 1248 in 5770 texts
# text 1249 in 5770 texts
# text 1250 in 5770 texts
# text 1251 in 5770 texts
# text 1252 in 5770 texts
# text 1253 in 5770 texts
# text 1254 in 5770 texts
# text 1255 in 5770 texts
# text 1256 in 5770 texts
# text 1257 in 5770 texts
# text 1258 in 5770 texts
# text 1259 in 5770 texts
# text 1260 in 5770 texts
# text 1261 in 5770 texts
# text 1262 in 5770 texts
# text 1263 in 5770 texts
# text 1264 in 5770 texts
# text 1265 in 5770 texts
# text 1266 in 5770 texts
# text 1267 in 5770 texts
# text 1268 in 5770 texts
# text 1269 in 5770 texts
# text 1270 in 5770 texts
# text 1271 in 5770 texts
# text 1272 in 5770 texts
# text 1273 in 5770 texts
# text 1274 in 5770 texts
# text 1275 in 5770 texts
# text 1276 in 5770 texts
# text 1277 in 5770 texts
# text 1278 in 5770 texts
# text 1279 in 5770 texts
# text 1280 in 5770 texts
# text 1281 in 5770 texts
# text 1282 in 5770 texts
# text 1283 in 5770 texts
# text 1284 in 5770 texts
# text 1285 in 5770 texts
# text 1286 in 5770 texts
# text 1287 in 5770 texts
# text 1288 in 5770 texts
# text 1289 in 5770 texts
# text 1290 in 5770 texts
# text 1291 in 5770 texts
# text 1292 in 5770 texts
# text 1293 in 5770 texts
# text 1294 in 5770 texts
# text 1295 in 5770 texts
# text 1296 in 5770 texts
# text 1297 in 5770 texts
# text 1298 in 5770 texts
# text 1299 in 5770 texts
# text 1300 in 5770 texts
# text 1301 in 5770 texts
# text 1302 in 5770 texts
# text 1303 in 5770 texts
# text 1304 in 5770 texts
# text 1305 in 5770 texts
# text 1306 in 5770 texts
# text 1307 in 5770 texts
# text 1308 in 5770 texts
# text 1309 in 5770 texts
# text 1310 in 5770 texts
# text 1311 in 5770 texts
# text 1312 in 5770 texts
# text 1313 in 5770 texts
# text 1314 in 5770 texts
# text 1315 in 5770 texts
# text 1316 in 5770 texts
# text 1317 in 5770 texts
# text 1318 in 5770 texts
# text 1319 in 5770 texts
# text 1320 in 5770 texts
# text 1321 in 5770 texts
# text 1322 in 5770 texts
# text 1323 in 5770 texts
# text 1324 in 5770 texts
# text 1325 in 5770 texts
# text 1326 in 5770 texts
# text 1327 in 5770 texts
# text 1328 in 5770 texts
# text 1329 in 5770 texts
# text 1330 in 5770 texts
# text 1331 in 5770 texts
# text 1332 in 5770 texts
# text 1333 in 5770 texts
# text 1334 in 5770 texts
# text 1335 in 5770 texts
# text 1336 in 5770 texts
# text 1337 in 5770 texts
# text 1338 in 5770 texts
# text 1339 in 5770 texts
# text 1340 in 5770 texts
# text 1341 in 5770 texts
# text 1342 in 5770 texts
# text 1343 in 5770 texts
# text 1344 in 5770 texts
# text 1345 in 5770 texts
# text 1346 in 5770 texts
# text 1347 in 5770 texts
# text 1348 in 5770 texts
# text 1349 in 5770 texts
# text 1350 in 5770 texts
# text 1351 in 5770 texts
# text 1352 in 5770 texts
# text 1353 in 5770 texts
# text 1354 in 5770 texts
# text 1355 in 5770 texts
# text 1356 in 5770 texts
# text 1357 in 5770 texts
# text 1358 in 5770 texts
# text 1359 in 5770 texts
# text 1360 in 5770 texts
# text 1361 in 5770 texts
# text 1362 in 5770 texts
# text 1363 in 5770 texts
# text 1364 in 5770 texts
# text 1365 in 5770 texts
# text 1366 in 5770 texts
# text 1367 in 5770 texts
# text 1368 in 5770 texts
# text 1369 in 5770 texts
# text 1370 in 5770 texts
# text 1371 in 5770 texts
# text 1372 in 5770 texts
# text 1373 in 5770 texts
# text 1374 in 5770 texts
# text 1375 in 5770 texts
# text 1376 in 5770 texts
# text 1377 in 5770 texts
# text 1378 in 5770 texts
# text 1379 in 5770 texts
# text 1380 in 5770 texts
# text 1381 in 5770 texts
# text 1382 in 5770 texts
# text 1383 in 5770 texts
# text 1384 in 5770 texts
# text 1385 in 5770 texts
# text 1386 in 5770 texts
# text 1387 in 5770 texts
# text 1388 in 5770 texts
# text 1389 in 5770 texts
# text 1390 in 5770 texts
# text 1391 in 5770 texts
# text 1392 in 5770 texts
# text 1393 in 5770 texts
# text 1394 in 5770 texts
# text 1395 in 5770 texts
# text 1396 in 5770 texts
# text 1397 in 5770 texts
# text 1398 in 5770 texts
# text 1399 in 5770 texts
# text 1400 in 5770 texts
# text 1401 in 5770 texts
# text 1402 in 5770 texts
# text 1403 in 5770 texts
# text 1404 in 5770 texts
# text 1405 in 5770 texts
# text 1406 in 5770 texts
# text 1407 in 5770 texts
# text 1408 in 5770 texts
# text 1409 in 5770 texts
# text 1410 in 5770 texts
# text 1411 in 5770 texts
# text 1412 in 5770 texts
# text 1413 in 5770 texts
# text 1414 in 5770 texts
# text 1415 in 5770 texts
# text 1416 in 5770 texts
# text 1417 in 5770 texts
# text 1418 in 5770 texts
# text 1419 in 5770 texts
# text 1420 in 5770 texts
# text 1421 in 5770 texts
# text 1422 in 5770 texts
# text 1423 in 5770 texts
# text 1424 in 5770 texts
# text 1425 in 5770 texts
# text 1426 in 5770 texts
# text 1427 in 5770 texts
# text 1428 in 5770 texts
# text 1429 in 5770 texts
# text 1430 in 5770 texts
# text 1431 in 5770 texts
# text 1432 in 5770 texts
# text 1433 in 5770 texts
# text 1434 in 5770 texts
# text 1435 in 5770 texts
# text 1436 in 5770 texts
# text 1437 in 5770 texts
# text 1438 in 5770 texts
# text 1439 in 5770 texts
# text 1440 in 5770 texts
# text 1441 in 5770 texts
# text 1442 in 5770 texts
# text 1443 in 5770 texts
# text 1444 in 5770 texts
# text 1445 in 5770 texts
# text 1446 in 5770 texts
# text 1447 in 5770 texts
# text 1448 in 5770 texts
# text 1449 in 5770 texts
# text 1450 in 5770 texts
# text 1451 in 5770 texts
# text 1452 in 5770 texts
# text 1453 in 5770 texts
# text 1454 in 5770 texts
# text 1455 in 5770 texts
# text 1456 in 5770 texts
# text 1457 in 5770 texts
# text 1458 in 5770 texts
# text 1459 in 5770 texts
# text 1460 in 5770 texts
# text 1461 in 5770 texts
# text 1462 in 5770 texts
# text 1463 in 5770 texts
# text 1464 in 5770 texts
# text 1465 in 5770 texts
# text 1466 in 5770 texts
# text 1467 in 5770 texts
# text 1468 in 5770 texts
# text 1469 in 5770 texts
# text 1470 in 5770 texts
# text 1471 in 5770 texts
# text 1472 in 5770 texts
# text 1473 in 5770 texts
# text 1474 in 5770 texts
# text 1475 in 5770 texts
# text 1476 in 5770 texts
# text 1477 in 5770 texts
# text 1478 in 5770 texts
# text 1479 in 5770 texts
# text 1480 in 5770 texts
# text 1481 in 5770 texts
# text 1482 in 5770 texts
# text 1483 in 5770 texts
# text 1484 in 5770 texts
# text 1485 in 5770 texts
# text 1486 in 5770 texts
# text 1487 in 5770 texts
# text 1488 in 5770 texts
# text 1489 in 5770 texts
# text 1490 in 5770 texts
# text 1491 in 5770 texts
# text 1492 in 5770 texts
# text 1493 in 5770 texts
# text 1494 in 5770 texts
# text 1495 in 5770 texts
# text 1496 in 5770 texts
# text 1497 in 5770 texts
# text 1498 in 5770 texts
# text 1499 in 5770 texts
# text 1500 in 5770 texts
# text 1501 in 5770 texts
# text 1502 in 5770 texts
# text 1503 in 5770 texts
# text 1504 in 5770 texts
# text 1505 in 5770 texts
# text 1506 in 5770 texts
# text 1507 in 5770 texts
# text 1508 in 5770 texts
# text 1509 in 5770 texts
# text 1510 in 5770 texts
# text 1511 in 5770 texts
# text 1512 in 5770 texts
# text 1513 in 5770 texts
# text 1514 in 5770 texts
# text 1515 in 5770 texts
# text 1516 in 5770 texts
# text 1517 in 5770 texts
# text 1518 in 5770 texts
# text 1519 in 5770 texts
# text 1520 in 5770 texts
# text 1521 in 5770 texts
# text 1522 in 5770 texts
# text 1523 in 5770 texts
# text 1524 in 5770 texts
# text 1525 in 5770 texts
# text 1526 in 5770 texts
# text 1527 in 5770 texts
# text 1528 in 5770 texts
# text 1529 in 5770 texts
# text 1530 in 5770 texts
# text 1531 in 5770 texts
# text 1532 in 5770 texts
# text 1533 in 5770 texts
# text 1534 in 5770 texts
# text 1535 in 5770 texts
# text 1536 in 5770 texts
# text 1537 in 5770 texts
# text 1538 in 5770 texts
# text 1539 in 5770 texts
# text 1540 in 5770 texts
# text 1541 in 5770 texts
# text 1542 in 5770 texts
# text 1543 in 5770 texts
# text 1544 in 5770 texts
# text 1545 in 5770 texts
# text 1546 in 5770 texts
# text 1547 in 5770 texts
# text 1548 in 5770 texts
# text 1549 in 5770 texts
# text 1550 in 5770 texts
# text 1551 in 5770 texts
# text 1552 in 5770 texts
# text 1553 in 5770 texts
# text 1554 in 5770 texts
# text 1555 in 5770 texts
# text 1556 in 5770 texts
# text 1557 in 5770 texts
# text 1558 in 5770 texts
# text 1559 in 5770 texts
# text 1560 in 5770 texts
# text 1561 in 5770 texts
# text 1562 in 5770 texts
# text 1563 in 5770 texts
# text 1564 in 5770 texts
# text 1565 in 5770 texts
# text 1566 in 5770 texts
# text 1567 in 5770 texts
# text 1568 in 5770 texts
# text 1569 in 5770 texts
# text 1570 in 5770 texts
# text 1571 in 5770 texts
# text 1572 in 5770 texts
# text 1573 in 5770 texts
# text 1574 in 5770 texts
# text 1575 in 5770 texts
# text 1576 in 5770 texts
# text 1577 in 5770 texts
# text 1578 in 5770 texts
# text 1579 in 5770 texts
# text 1580 in 5770 texts
# text 1581 in 5770 texts
# text 1582 in 5770 texts
# text 1583 in 5770 texts
# text 1584 in 5770 texts
# text 1585 in 5770 texts
# text 1586 in 5770 texts
# text 1587 in 5770 texts
# text 1588 in 5770 texts
# text 1589 in 5770 texts
# text 1590 in 5770 texts
# text 1591 in 5770 texts
# text 1592 in 5770 texts
# text 1593 in 5770 texts
# text 1594 in 5770 texts
# text 1595 in 5770 texts
# text 1596 in 5770 texts
# text 1597 in 5770 texts
# text 1598 in 5770 texts
# text 1599 in 5770 texts
# text 1600 in 5770 texts
# text 1601 in 5770 texts
# text 1602 in 5770 texts
# text 1603 in 5770 texts
# text 1604 in 5770 texts
# text 1605 in 5770 texts
# text 1606 in 5770 texts
# text 1607 in 5770 texts
# text 1608 in 5770 texts
# text 1609 in 5770 texts
# text 1610 in 5770 texts
# text 1611 in 5770 texts
# text 1612 in 5770 texts
# text 1613 in 5770 texts
# text 1614 in 5770 texts
# text 1615 in 5770 texts
# text 1616 in 5770 texts
# text 1617 in 5770 texts
# text 1618 in 5770 texts
# text 1619 in 5770 texts
# text 1620 in 5770 texts
# text 1621 in 5770 texts
# text 1622 in 5770 texts
# text 1623 in 5770 texts
# text 1624 in 5770 texts
# text 1625 in 5770 texts
# text 1626 in 5770 texts
# text 1627 in 5770 texts
# text 1628 in 5770 texts
# text 1629 in 5770 texts
# text 1630 in 5770 texts
# text 1631 in 5770 texts
# text 1632 in 5770 texts
# text 1633 in 5770 texts
# text 1634 in 5770 texts
# text 1635 in 5770 texts
# text 1636 in 5770 texts
# text 1637 in 5770 texts
# text 1638 in 5770 texts
# text 1639 in 5770 texts
# text 1640 in 5770 texts
# text 1641 in 5770 texts
# text 1642 in 5770 texts
# text 1643 in 5770 texts
# text 1644 in 5770 texts
# text 1645 in 5770 texts
# text 1646 in 5770 texts
# text 1647 in 5770 texts
# text 1648 in 5770 texts
# text 1649 in 5770 texts
# text 1650 in 5770 texts
# text 1651 in 5770 texts
# text 1652 in 5770 texts
# text 1653 in 5770 texts
# text 1654 in 5770 texts
# text 1655 in 5770 texts
# text 1656 in 5770 texts
# text 1657 in 5770 texts
# text 1658 in 5770 texts
# text 1659 in 5770 texts
# text 1660 in 5770 texts
# text 1661 in 5770 texts
# text 1662 in 5770 texts
# text 1663 in 5770 texts
# text 1664 in 5770 texts
# text 1665 in 5770 texts
# text 1666 in 5770 texts
# text 1667 in 5770 texts
# text 1668 in 5770 texts
# text 1669 in 5770 texts
# text 1670 in 5770 texts
# text 1671 in 5770 texts
# text 1672 in 5770 texts
# text 1673 in 5770 texts
# text 1674 in 5770 texts
# text 1675 in 5770 texts
# text 1676 in 5770 texts
# text 1677 in 5770 texts
# text 1678 in 5770 texts
# text 1679 in 5770 texts
# text 1680 in 5770 texts
# text 1681 in 5770 texts
# text 1682 in 5770 texts
# text 1683 in 5770 texts
# text 1684 in 5770 texts
# text 1685 in 5770 texts
# text 1686 in 5770 texts
# text 1687 in 5770 texts
# text 1688 in 5770 texts
# text 1689 in 5770 texts
# text 1690 in 5770 texts
# text 1691 in 5770 texts
# text 1692 in 5770 texts
# text 1693 in 5770 texts
# text 1694 in 5770 texts
# text 1695 in 5770 texts
# text 1696 in 5770 texts
# text 1697 in 5770 texts
# text 1698 in 5770 texts
# text 1699 in 5770 texts
# text 1700 in 5770 texts
# text 1701 in 5770 texts
# text 1702 in 5770 texts
# text 1703 in 5770 texts
# text 1704 in 5770 texts
# text 1705 in 5770 texts
# text 1706 in 5770 texts
# text 1707 in 5770 texts
# text 1708 in 5770 texts
# text 1709 in 5770 texts
# text 1710 in 5770 texts
# text 1711 in 5770 texts
# text 1712 in 5770 texts
# text 1713 in 5770 texts
# text 1714 in 5770 texts
# text 1715 in 5770 texts
# text 1716 in 5770 texts
# text 1717 in 5770 texts
# text 1718 in 5770 texts
# text 1719 in 5770 texts
# text 1720 in 5770 texts
# text 1721 in 5770 texts
# text 1722 in 5770 texts
# text 1723 in 5770 texts
# text 1724 in 5770 texts
# text 1725 in 5770 texts
# text 1726 in 5770 texts
# text 1727 in 5770 texts
# text 1728 in 5770 texts
# text 1729 in 5770 texts
# text 1730 in 5770 texts
# text 1731 in 5770 texts
# text 1732 in 5770 texts
# text 1733 in 5770 texts
# text 1734 in 5770 texts
# text 1735 in 5770 texts
# text 1736 in 5770 texts
# text 1737 in 5770 texts
# text 1738 in 5770 texts
# text 1739 in 5770 texts
# text 1740 in 5770 texts
# text 1741 in 5770 texts
# text 1742 in 5770 texts
# text 1743 in 5770 texts
# text 1744 in 5770 texts
# text 1745 in 5770 texts
# text 1746 in 5770 texts
# text 1747 in 5770 texts
# text 1748 in 5770 texts
# text 1749 in 5770 texts
# text 1750 in 5770 texts
# text 1751 in 5770 texts
# text 1752 in 5770 texts
# text 1753 in 5770 texts
# text 1754 in 5770 texts
# text 1755 in 5770 texts
# text 1756 in 5770 texts
# text 1757 in 5770 texts
# text 1758 in 5770 texts
# text 1759 in 5770 texts
# text 1760 in 5770 texts
# text 1761 in 5770 texts
# text 1762 in 5770 texts
# text 1763 in 5770 texts
# text 1764 in 5770 texts
# text 1765 in 5770 texts
# text 1766 in 5770 texts
# text 1767 in 5770 texts
# text 1768 in 5770 texts
# text 1769 in 5770 texts
# text 1770 in 5770 texts
# text 1771 in 5770 texts
# text 1772 in 5770 texts
# text 1773 in 5770 texts
# text 1774 in 5770 texts
# text 1775 in 5770 texts
# text 1776 in 5770 texts
# text 1777 in 5770 texts
# text 1778 in 5770 texts
# text 1779 in 5770 texts
# text 1780 in 5770 texts
# text 1781 in 5770 texts
# text 1782 in 5770 texts
# text 1783 in 5770 texts
# text 1784 in 5770 texts
# text 1785 in 5770 texts
# text 1786 in 5770 texts
# text 1787 in 5770 texts
# text 1788 in 5770 texts
# text 1789 in 5770 texts
# text 1790 in 5770 texts
# text 1791 in 5770 texts
# text 1792 in 5770 texts
# text 1793 in 5770 texts
# text 1794 in 5770 texts
# text 1795 in 5770 texts
# text 1796 in 5770 texts
# text 1797 in 5770 texts
# text 1798 in 5770 texts
# text 1799 in 5770 texts
# text 1800 in 5770 texts
# text 1801 in 5770 texts
# text 1802 in 5770 texts
# text 1803 in 5770 texts
# text 1804 in 5770 texts
# text 1805 in 5770 texts
# text 1806 in 5770 texts
# text 1807 in 5770 texts
# text 1808 in 5770 texts
# text 1809 in 5770 texts
# text 1810 in 5770 texts
# text 1811 in 5770 texts
# text 1812 in 5770 texts
# text 1813 in 5770 texts
# text 1814 in 5770 texts
# text 1815 in 5770 texts
# text 1816 in 5770 texts
# text 1817 in 5770 texts
# text 1818 in 5770 texts
# text 1819 in 5770 texts
# text 1820 in 5770 texts
# text 1821 in 5770 texts
# text 1822 in 5770 texts
# text 1823 in 5770 texts
# text 1824 in 5770 texts
# text 1825 in 5770 texts
# text 1826 in 5770 texts
# text 1827 in 5770 texts
# text 1828 in 5770 texts
# text 1829 in 5770 texts
# text 1830 in 5770 texts
# text 1831 in 5770 texts
# text 1832 in 5770 texts
# text 1833 in 5770 texts
# text 1834 in 5770 texts
# text 1835 in 5770 texts
# text 1836 in 5770 texts
# text 1837 in 5770 texts
# text 1838 in 5770 texts
# text 1839 in 5770 texts
# text 1840 in 5770 texts
# text 1841 in 5770 texts
# text 1842 in 5770 texts
# text 1843 in 5770 texts
# text 1844 in 5770 texts
# text 1845 in 5770 texts
# text 1846 in 5770 texts
# text 1847 in 5770 texts
# text 1848 in 5770 texts
# text 1849 in 5770 texts
# text 1850 in 5770 texts
# text 1851 in 5770 texts
# text 1852 in 5770 texts
# text 1853 in 5770 texts
# text 1854 in 5770 texts
# text 1855 in 5770 texts
# text 1856 in 5770 texts
# text 1857 in 5770 texts
# text 1858 in 5770 texts
# text 1859 in 5770 texts
# text 1860 in 5770 texts
# text 1861 in 5770 texts
# text 1862 in 5770 texts
# text 1863 in 5770 texts
# text 1864 in 5770 texts
# text 1865 in 5770 texts
# text 1866 in 5770 texts
# text 1867 in 5770 texts
# text 1868 in 5770 texts
# text 1869 in 5770 texts
# text 1870 in 5770 texts
# text 1871 in 5770 texts
# text 1872 in 5770 texts
# text 1873 in 5770 texts
# text 1874 in 5770 texts
# text 1875 in 5770 texts
# text 1876 in 5770 texts
# text 1877 in 5770 texts
# text 1878 in 5770 texts
# text 1879 in 5770 texts
# text 1880 in 5770 texts
# text 1881 in 5770 texts
# text 1882 in 5770 texts
# text 1883 in 5770 texts
# text 1884 in 5770 texts
# text 1885 in 5770 texts
# text 1886 in 5770 texts
# text 1887 in 5770 texts
# text 1888 in 5770 texts
# text 1889 in 5770 texts
# text 1890 in 5770 texts
# text 1891 in 5770 texts
# text 1892 in 5770 texts
# text 1893 in 5770 texts
# text 1894 in 5770 texts
# text 1895 in 5770 texts
# text 1896 in 5770 texts
# text 1897 in 5770 texts
# text 1898 in 5770 texts
# text 1899 in 5770 texts
# text 1900 in 5770 texts
# text 1901 in 5770 texts
# text 1902 in 5770 texts
# text 1903 in 5770 texts
# text 1904 in 5770 texts
# text 1905 in 5770 texts
# text 1906 in 5770 texts
# text 1907 in 5770 texts
# text 1908 in 5770 texts
# text 1909 in 5770 texts
# text 1910 in 5770 texts
# text 1911 in 5770 texts
# text 1912 in 5770 texts
# text 1913 in 5770 texts
# text 1914 in 5770 texts
# text 1915 in 5770 texts
# text 1916 in 5770 texts
# text 1917 in 5770 texts
# text 1918 in 5770 texts
# text 1919 in 5770 texts
# text 1920 in 5770 texts
# text 1921 in 5770 texts
# text 1922 in 5770 texts
# text 1923 in 5770 texts
# text 1924 in 5770 texts
# text 1925 in 5770 texts
# text 1926 in 5770 texts
# text 1927 in 5770 texts
# text 1928 in 5770 texts
# text 1929 in 5770 texts
# text 1930 in 5770 texts
# text 1931 in 5770 texts
# text 1932 in 5770 texts
# text 1933 in 5770 texts
# text 1934 in 5770 texts
# text 1935 in 5770 texts
# text 1936 in 5770 texts
# text 1937 in 5770 texts
# text 1938 in 5770 texts
# text 1939 in 5770 texts
# text 1940 in 5770 texts
# text 1941 in 5770 texts
# text 1942 in 5770 texts
# text 1943 in 5770 texts
# text 1944 in 5770 texts
# text 1945 in 5770 texts
# text 1946 in 5770 texts
# text 1947 in 5770 texts
# text 1948 in 5770 texts
# text 1949 in 5770 texts
# text 1950 in 5770 texts
# text 1951 in 5770 texts
# text 1952 in 5770 texts
# text 1953 in 5770 texts
# text 1954 in 5770 texts
# text 1955 in 5770 texts
# text 1956 in 5770 texts
# text 1957 in 5770 texts
# text 1958 in 5770 texts
# text 1959 in 5770 texts
# text 1960 in 5770 texts
# text 1961 in 5770 texts
# text 1962 in 5770 texts
# text 1963 in 5770 texts
# text 1964 in 5770 texts
# text 1965 in 5770 texts
# text 1966 in 5770 texts
# text 1967 in 5770 texts
# text 1968 in 5770 texts
# text 1969 in 5770 texts
# text 1970 in 5770 texts
# text 1971 in 5770 texts
# text 1972 in 5770 texts
# text 1973 in 5770 texts
# text 1974 in 5770 texts
# text 1975 in 5770 texts
# text 1976 in 5770 texts
# text 1977 in 5770 texts
# text 1978 in 5770 texts
# text 1979 in 5770 texts
# text 1980 in 5770 texts
# text 1981 in 5770 texts
# text 1982 in 5770 texts
# text 1983 in 5770 texts
# text 1984 in 5770 texts
# text 1985 in 5770 texts
# text 1986 in 5770 texts
# text 1987 in 5770 texts
# text 1988 in 5770 texts
# text 1989 in 5770 texts
# text 1990 in 5770 texts
# text 1991 in 5770 texts
# text 1992 in 5770 texts
# text 1993 in 5770 texts
# text 1994 in 5770 texts
# text 1995 in 5770 texts
# text 1996 in 5770 texts
# text 1997 in 5770 texts
# text 1998 in 5770 texts
# text 1999 in 5770 texts
# text 2000 in 5770 texts
# text 2001 in 5770 texts
# text 2002 in 5770 texts
# text 2003 in 5770 texts
# text 2004 in 5770 texts
# text 2005 in 5770 texts
# text 2006 in 5770 texts
# text 2007 in 5770 texts
# text 2008 in 5770 texts
# text 2009 in 5770 texts
# text 2010 in 5770 texts
# text 2011 in 5770 texts
# text 2012 in 5770 texts
# text 2013 in 5770 texts
# text 2014 in 5770 texts
# text 2015 in 5770 texts
# text 2016 in 5770 texts
# text 2017 in 5770 texts
# text 2018 in 5770 texts
# text 2019 in 5770 texts
# text 2020 in 5770 texts
# text 2021 in 5770 texts
# text 2022 in 5770 texts
# text 2023 in 5770 texts
# text 2024 in 5770 texts
# text 2025 in 5770 texts
# text 2026 in 5770 texts
# text 2027 in 5770 texts
# text 2028 in 5770 texts
# text 2029 in 5770 texts
# text 2030 in 5770 texts
# text 2031 in 5770 texts
# text 2032 in 5770 texts
# text 2033 in 5770 texts
# text 2034 in 5770 texts
# text 2035 in 5770 texts
# text 2036 in 5770 texts
# text 2037 in 5770 texts
# text 2038 in 5770 texts
# text 2039 in 5770 texts
# text 2040 in 5770 texts
# text 2041 in 5770 texts
# text 2042 in 5770 texts
# text 2043 in 5770 texts
# text 2044 in 5770 texts
# text 2045 in 5770 texts
# ...
# text 3719 in 5770 texts
# text 3720 in 5770 texts
# text 3721 in 5770 texts
# text 3722 in 5770 texts
# text 3723 in 5770 texts
# text 3724 in 5770 texts
# text 3725 in 5770 texts
# text 3726 in 5770 texts
# text 3727 in 5770 texts
# text 3728 in 5770 texts
# text 3729 in 5770 texts
# text 3730 in 5770 texts
# text 3731 in 5770 texts
# text 3732 in 5770 texts
# text 3733 in 5770 texts
# text 3734 in 5770 texts
# text 3735 in 5770 texts
# text 3736 in 5770 texts
# text 3737 in 5770 texts
# text 3738 in 5770 texts
# text 3739 in 5770 texts
# text 3740 in 5770 texts
# text 3741 in 5770 texts
# text 3742 in 5770 texts
# text 3743 in 5770 texts
# text 3744 in 5770 texts
# text 3745 in 5770 texts
# text 3746 in 5770 texts
# text 3747 in 5770 texts
# text 3748 in 5770 texts
# text 3749 in 5770 texts
# text 3750 in 5770 texts
# text 3751 in 5770 texts
# text 3752 in 5770 texts
# text 3753 in 5770 texts
# text 3754 in 5770 texts
# text 3755 in 5770 texts
# text 3756 in 5770 texts
# text 3757 in 5770 texts
# text 3758 in 5770 texts
# text 3759 in 5770 texts
# text 3760 in 5770 texts
# text 3761 in 5770 texts
# text 3762 in 5770 texts
# text 3763 in 5770 texts
# text 3764 in 5770 texts
# text 3765 in 5770 texts
# text 3766 in 5770 texts
# text 3767 in 5770 texts
# text 3768 in 5770 texts
# text 3769 in 5770 texts
# text 3770 in 5770 texts
# text 3771 in 5770 texts
# text 3772 in 5770 texts
# text 3773 in 5770 texts
# text 3774 in 5770 texts
# text 3775 in 5770 texts
# text 3776 in 5770 texts
# text 3777 in 5770 texts
# text 3778 in 5770 texts
# text 3779 in 5770 texts
# text 3780 in 5770 texts
# text 3781 in 5770 texts
# text 3782 in 5770 texts
# text 3783 in 5770 texts
# text 3784 in 5770 texts
# text 3785 in 5770 texts
# text 3786 in 5770 texts
# text 3787 in 5770 texts
# text 3788 in 5770 texts
# text 3789 in 5770 texts
# text 3790 in 5770 texts
# text 3791 in 5770 texts
# text 3792 in 5770 texts
# text 3793 in 5770 texts
# text 3794 in 5770 texts
# text 3795 in 5770 texts
# text 3796 in 5770 texts
# text 3797 in 5770 texts
# text 3798 in 5770 texts
# text 3799 in 5770 texts
# text 3800 in 5770 texts
# text 3801 in 5770 texts
# text 3802 in 5770 texts
# text 3803 in 5770 texts
# text 3804 in 5770 texts
# text 3805 in 5770 texts
# text 3806 in 5770 texts
# text 3807 in 5770 texts
# text 3808 in 5770 texts
# text 3809 in 5770 texts
# text 3810 in 5770 texts
# text 3811 in 5770 texts
# text 3812 in 5770 texts
# text 3813 in 5770 texts
# text 3814 in 5770 texts
# text 3815 in 5770 texts
# text 3816 in 5770 texts
# text 3817 in 5770 texts
# text 3818 in 5770 texts
# text 3819 in 5770 texts
# text 3820 in 5770 texts
# text 3821 in 5770 texts
# text 3822 in 5770 texts
# text 3823 in 5770 texts
# text 3824 in 5770 texts
# text 3825 in 5770 texts
# text 3826 in 5770 texts
# text 3827 in 5770 texts
# text 3828 in 5770 texts
# text 3829 in 5770 texts
# text 3830 in 5770 texts
# text 3831 in 5770 texts
# text 3832 in 5770 texts
# text 3833 in 5770 texts
# text 3834 in 5770 texts
# text 3835 in 5770 texts
# text 3836 in 5770 texts
# text 3837 in 5770 texts
# text 3838 in 5770 texts
# text 3839 in 5770 texts
# text 3840 in 5770 texts
# text 3841 in 5770 texts
# text 3842 in 5770 texts
# text 3843 in 5770 texts
# text 3844 in 5770 texts
# text 3845 in 5770 texts
# text 3846 in 5770 texts
# text 3847 in 5770 texts
# text 3848 in 5770 texts
# text 3849 in 5770 texts
# text 3850 in 5770 texts
# text 3851 in 5770 texts
# text 3852 in 5770 texts
# text 3853 in 5770 texts
# text 3854 in 5770 texts
# text 3855 in 5770 texts
# text 3856 in 5770 texts
# text 3857 in 5770 texts
# text 3858 in 5770 texts
# text 3859 in 5770 texts
# text 3860 in 5770 texts
# text 3861 in 5770 texts
# text 3862 in 5770 texts
# text 3863 in 5770 texts
# text 3864 in 5770 texts
# text 3865 in 5770 texts
# text 3866 in 5770 texts
# text 3867 in 5770 texts
# text 3868 in 5770 texts
# text 3869 in 5770 texts
# text 3870 in 5770 texts
# text 3871 in 5770 texts
# text 3872 in 5770 texts
# text 3873 in 5770 texts
# text 3874 in 5770 texts
# text 3875 in 5770 texts
# text 3876 in 5770 texts
# text 3877 in 5770 texts
# text 3878 in 5770 texts
# text 3879 in 5770 texts
# text 3880 in 5770 texts
# text 3881 in 5770 texts
# text 3882 in 5770 texts
# text 3883 in 5770 texts
# text 3884 in 5770 texts
# text 3885 in 5770 texts
# text 3886 in 5770 texts
# text 3887 in 5770 texts
# text 3888 in 5770 texts
# text 3889 in 5770 texts
# text 3890 in 5770 texts
# text 3891 in 5770 texts
# text 3892 in 5770 texts
# text 3893 in 5770 texts
# text 3894 in 5770 texts
# text 3895 in 5770 texts
# text 3896 in 5770 texts
# text 3897 in 5770 texts
# text 3898 in 5770 texts
# text 3899 in 5770 texts
# text 3900 in 5770 texts
# text 3901 in 5770 texts
# text 3902 in 5770 texts
# text 3903 in 5770 texts
# text 3904 in 5770 texts
# text 3905 in 5770 texts
# text 3906 in 5770 texts
# text 3907 in 5770 texts
# text 3908 in 5770 texts
# text 3909 in 5770 texts
# text 3910 in 5770 texts
# text 3911 in 5770 texts
# text 3912 in 5770 texts
# text 3913 in 5770 texts
# text 3914 in 5770 texts
# text 3915 in 5770 texts
# text 3916 in 5770 texts
# text 3917 in 5770 texts
# text 3918 in 5770 texts
# text 3919 in 5770 texts
# text 3920 in 5770 texts
# text 3921 in 5770 texts
# text 3922 in 5770 texts
# text 3923 in 5770 texts
# text 3924 in 5770 texts
# text 3925 in 5770 texts
# text 3926 in 5770 texts
# text 3927 in 5770 texts
# text 3928 in 5770 texts
# text 3929 in 5770 texts
# text 3930 in 5770 texts
# text 3931 in 5770 texts
# text 3932 in 5770 texts
# text 3933 in 5770 texts
# text 3934 in 5770 texts
# text 3935 in 5770 texts
# text 3936 in 5770 texts
# text 3937 in 5770 texts
# text 3938 in 5770 texts
# text 3939 in 5770 texts
# text 3940 in 5770 texts
# text 3941 in 5770 texts
# text 3942 in 5770 texts
# text 3943 in 5770 texts
# text 3944 in 5770 texts
# text 3945 in 5770 texts
# text 3946 in 5770 texts
# text 3947 in 5770 texts
# text 3948 in 5770 texts
# text 3949 in 5770 texts
# text 3950 in 5770 texts
# text 3951 in 5770 texts
# text 3952 in 5770 texts
# text 3953 in 5770 texts
# text 3954 in 5770 texts
# text 3955 in 5770 texts
# text 3956 in 5770 texts
# text 3957 in 5770 texts
# text 3958 in 5770 texts
# text 3959 in 5770 texts
# text 3960 in 5770 texts
# text 3961 in 5770 texts
# text 3962 in 5770 texts
# text 3963 in 5770 texts
# text 3964 in 5770 texts
# text 3965 in 5770 texts
# text 3966 in 5770 texts
# text 3967 in 5770 texts
# text 3968 in 5770 texts
# text 3969 in 5770 texts
# text 3970 in 5770 texts
# text 3971 in 5770 texts
# text 3972 in 5770 texts
# text 3973 in 5770 texts
# text 3974 in 5770 texts
# text 3975 in 5770 texts
# text 3976 in 5770 texts
# text 3977 in 5770 texts
# text 3978 in 5770 texts
# text 3979 in 5770 texts
# text 3980 in 5770 texts
# text 3981 in 5770 texts
# text 3982 in 5770 texts
# text 3983 in 5770 texts
# text 3984 in 5770 texts
# text 3985 in 5770 texts
# text 3986 in 5770 texts
# text 3987 in 5770 texts
# text 3988 in 5770 texts
# text 3989 in 5770 texts
# text 3990 in 5770 texts
# text 3991 in 5770 texts
# text 3992 in 5770 texts
# text 3993 in 5770 texts
# text 3994 in 5770 texts
# text 3995 in 5770 texts
# text 3996 in 5770 texts
# text 3997 in 5770 texts
# text 3998 in 5770 texts
# text 3999 in 5770 texts
# text 4000 in 5770 texts
# text 4001 in 5770 texts
# text 4002 in 5770 texts
# text 4003 in 5770 texts
# text 4004 in 5770 texts
# text 4005 in 5770 texts
# text 4006 in 5770 texts
# text 4007 in 5770 texts
# text 4008 in 5770 texts
# text 4009 in 5770 texts
# text 4010 in 5770 texts
# text 4011 in 5770 texts
# text 4012 in 5770 texts
# text 4013 in 5770 texts
# text 4014 in 5770 texts
# text 4015 in 5770 texts
# text 4016 in 5770 texts
# text 4017 in 5770 texts
# text 4018 in 5770 texts
# text 4019 in 5770 texts
# text 4020 in 5770 texts
# text 4021 in 5770 texts
# text 4022 in 5770 texts
# text 4023 in 5770 texts
# text 4024 in 5770 texts
# text 4025 in 5770 texts
# text 4026 in 5770 texts
# text 4027 in 5770 texts
# text 4028 in 5770 texts
# text 4029 in 5770 texts
# text 4030 in 5770 texts
# text 4031 in 5770 texts
# text 4032 in 5770 texts
# text 4033 in 5770 texts
# text 4034 in 5770 texts
# text 4035 in 5770 texts
# text 4036 in 5770 texts
# text 4037 in 5770 texts
# text 4038 in 5770 texts
# text 4039 in 5770 texts
# text 4040 in 5770 texts
# text 4041 in 5770 texts
# text 4042 in 5770 texts
# text 4043 in 5770 texts
# text 4044 in 5770 texts
# text 4045 in 5770 texts
# text 4046 in 5770 texts
# text 4047 in 5770 texts
# text 4048 in 5770 texts
# text 4049 in 5770 texts
# text 4050 in 5770 texts
# text 4051 in 5770 texts
# text 4052 in 5770 texts
# text 4053 in 5770 texts
# text 4054 in 5770 texts
# text 4055 in 5770 texts
# text 4056 in 5770 texts
# text 4057 in 5770 texts
# text 4058 in 5770 texts
# text 4059 in 5770 texts
# text 4060 in 5770 texts
# text 4061 in 5770 texts
# text 4062 in 5770 texts
# text 4063 in 5770 texts
# text 4064 in 5770 texts
# text 4065 in 5770 texts
# text 4066 in 5770 texts
# text 4067 in 5770 texts
# text 4068 in 5770 texts
# text 4069 in 5770 texts
# text 4070 in 5770 texts
# text 4071 in 5770 texts
# text 4072 in 5770 texts
# text 4073 in 5770 texts
# text 4074 in 5770 texts
# text 4075 in 5770 texts
# text 4076 in 5770 texts
# text 4077 in 5770 texts
# text 4078 in 5770 texts
# text 4079 in 5770 texts
# text 4080 in 5770 texts
# text 4081 in 5770 texts
# text 4082 in 5770 texts
# text 4083 in 5770 texts
# text 4084 in 5770 texts
# text 4085 in 5770 texts
# text 4086 in 5770 texts
# text 4087 in 5770 texts
# text 4088 in 5770 texts
# text 4089 in 5770 texts
# text 4090 in 5770 texts
# text 4091 in 5770 texts
# text 4092 in 5770 texts
# text 4093 in 5770 texts
# text 4094 in 5770 texts
# text 4095 in 5770 texts
# text 4096 in 5770 texts
# text 4097 in 5770 texts
# text 4098 in 5770 texts
# text 4099 in 5770 texts
# text 4100 in 5770 texts
# text 4101 in 5770 texts
# text 4102 in 5770 texts
# text 4103 in 5770 texts
# text 4104 in 5770 texts
# text 4105 in 5770 texts
# text 4106 in 5770 texts
# text 4107 in 5770 texts
# text 4108 in 5770 texts
# text 4109 in 5770 texts
# text 4110 in 5770 texts
# text 4111 in 5770 texts
# text 4112 in 5770 texts
# text 4113 in 5770 texts
# text 4114 in 5770 texts
# text 4115 in 5770 texts
# text 4116 in 5770 texts
# text 4117 in 5770 texts
# text 4118 in 5770 texts
# text 4119 in 5770 texts
# text 4120 in 5770 texts
# text 4121 in 5770 texts
# text 4122 in 5770 texts
# text 4123 in 5770 texts
# text 4124 in 5770 texts
# text 4125 in 5770 texts
# text 4126 in 5770 texts
# text 4127 in 5770 texts
# text 4128 in 5770 texts
# text 4129 in 5770 texts
# text 4130 in 5770 texts
# text 4131 in 5770 texts
# text 4132 in 5770 texts
# text 4133 in 5770 texts
# text 4134 in 5770 texts
# text 4135 in 5770 texts
# text 4136 in 5770 texts
# text 4137 in 5770 texts
# text 4138 in 5770 texts
# text 4139 in 5770 texts
# text 4140 in 5770 texts
# text 4141 in 5770 texts
# text 4142 in 5770 texts
# text 4143 in 5770 texts
# text 4144 in 5770 texts
# text 4145 in 5770 texts
# text 4146 in 5770 texts
# text 4147 in 5770 texts
# text 4148 in 5770 texts
# text 4149 in 5770 texts
# text 4150 in 5770 texts
# text 4151 in 5770 texts
# text 4152 in 5770 texts
# text 4153 in 5770 texts
# text 4154 in 5770 texts
# text 4155 in 5770 texts
# text 4156 in 5770 texts
# text 4157 in 5770 texts
# text 4158 in 5770 texts
# text 4159 in 5770 texts
# text 4160 in 5770 texts
# text 4161 in 5770 texts
# text 4162 in 5770 texts
# text 4163 in 5770 texts
# text 4164 in 5770 texts
# text 4165 in 5770 texts
# text 4166 in 5770 texts
# text 4167 in 5770 texts
# text 4168 in 5770 texts
# text 4169 in 5770 texts
# text 4170 in 5770 texts
# text 4171 in 5770 texts
# text 4172 in 5770 texts
# text 4173 in 5770 texts
# text 4174 in 5770 texts
# text 4175 in 5770 texts
# text 4176 in 5770 texts
# text 4177 in 5770 texts
# text 4178 in 5770 texts
# text 4179 in 5770 texts
# text 4180 in 5770 texts
# text 4181 in 5770 texts
# text 4182 in 5770 texts
# text 4183 in 5770 texts
# text 4184 in 5770 texts
# text 4185 in 5770 texts
# text 4186 in 5770 texts
# text 4187 in 5770 texts
# text 4188 in 5770 texts
# text 4189 in 5770 texts
# text 4190 in 5770 texts
# text 4191 in 5770 texts
# text 4192 in 5770 texts
# text 4193 in 5770 texts
# text 4194 in 5770 texts
# text 4195 in 5770 texts
# text 4196 in 5770 texts
# text 4197 in 5770 texts
# text 4198 in 5770 texts
# text 4199 in 5770 texts
# text 4200 in 5770 texts
# text 4201 in 5770 texts
# text 4202 in 5770 texts
# text 4203 in 5770 texts
# text 4204 in 5770 texts
# text 4205 in 5770 texts
# text 4206 in 5770 texts
# text 4207 in 5770 texts
# text 4208 in 5770 texts
# text 4209 in 5770 texts
# text 4210 in 5770 texts
# text 4211 in 5770 texts
# text 4212 in 5770 texts
# text 4213 in 5770 texts
# text 4214 in 5770 texts
# text 4215 in 5770 texts
# text 4216 in 5770 texts
# text 4217 in 5770 texts
# text 4218 in 5770 texts
# text 4219 in 5770 texts
# text 4220 in 5770 texts
# text 4221 in 5770 texts
# text 4222 in 5770 texts
# text 4223 in 5770 texts
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 3
#       1 for i in range(0, len(texts_list_test)):
#       2     print(f"text {i} in {len(texts_list_test)} texts")
# ----> 3     summary_result = summarize_text(model, tokenizer, texts_list_test[i], device)
#       4     summary_result_test.append(summary_result)
#
# Cell In[33], line 19, in summarize_text(model, tokenizer, text, device, max_input_length, max_output_length, num_beams)
#      17 # Generate summary
#      18 with torch.no_grad():
# ---> 19     summary_ids = model.generate(
#      20         input_ids=input_ids,
#      21         attention_mask=attention_mask,
#      22         max_length=max_output_length,
#      23         num_beams=num_beams,
#      24         length_penalty=2.0,
#      25         early_stopping=True
#      26     )
#      28 # Decode summary
#      29 summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True, clean_up_tokenization_spaces=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\generation\utils.py:1638, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1622     result = self._sample(
#    1623         input_ids,
#    1624         logits_processor=prepared_logits_processor,
#    (...)
#    1633         **model_kwargs,
#    1634     )
#    1636 elif generation_mode == GenerationMode.BEAM_SEARCH:
#    1637     # 11. prepare beam search scorer
# -> 1638     beam_scorer = BeamSearchScorer(
#    1639         batch_size=batch_size,
#    1640         num_beams=generation_config.num_beams,
#    1641         device=inputs_tensor.device,
#    1642         length_penalty=generation_config.length_penalty,
#    1643         do_early_stopping=generation_config.early_stopping,
#    1644         num_beam_hyps_to_keep=generation_config.num_return_sequences,
#    1645         max_length=generation_config.max_length,
#    1646     )
#    1647     # 12. interleave input_ids with `num_beams` additional sequences per batch
#    1648     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1649         input_ids=input_ids,
#    1650         expand_size=generation_config.num_beams,
#    1651         is_encoder_decoder=self.config.is_encoder_decoder,
#    1652         **model_kwargs,
#    1653     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\generation\beam_search.py:195, in BeamSearchScorer.__init__(self, batch_size, num_beams, device, length_penalty, do_early_stopping, num_beam_hyps_to_keep, num_beam_groups, max_length)
#     184 self._beam_hyps = [
#     185     BeamHypotheses(
#     186         num_beams=self.group_size,
#    (...)
#     191     for _ in range(batch_size * self.num_beam_groups)
#     192 ]
#     193 # self._done[i*self.num_beam_groups+j] indicates whether the generation of the beam_hyps of the j-th group
#     194 # in the i-th mini-batch is complete.
# --> 195 self._done = torch.tensor(
#     196     [False for _ in range(batch_size * self.num_beam_groups)], dtype=torch.bool, device=self.device
#     197 )
#     199 if not isinstance(num_beams, int) or num_beams <= 1:
#     200     raise ValueError(
#     201         f"`num_beams` has to be an integer strictly greater than 1, but is {num_beams}. For `num_beams` == 1,"
#     202         " one should make use of `greedy_search` instead."
#     203     )
#
# KeyboardInterrupt:

# %%
with open('model_result.jsonl', 'w', encoding='utf-8') as f:
    for i in range(len(summary_result_test)):
        obj = {
            'text': texts_list_test[i],
            'expected_summary': summary_list_test[i],
            'generated_summary': summary_result_test[i]
        }
        f.write(json.dumps(obj, ensure_ascii=False) + '\n')

# %%
len(summary_result_test)
# Out:
# 4223
